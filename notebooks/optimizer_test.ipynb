# %%
import gymnasium as gym
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from src.optimization.optimization_functions.convex_function import ConvexFunction
from src.optimization.optimization_functions.convex_function_w_noise import ConvexFunctionWithNoise
from src.optimization.optimization_methods import gradient_descent_optimizer, adam_optimizer

seed = 1337
in_features = 2
scale = 1.0

graphics_count = 3

dims = [3, 5, 10, 100]

rng = np.random.default_rng(seed)

# %%
x0 = np.zeros(in_features)

# %% [markdown]
# Convex optimization (dim = 2)

# %%
for i in range(graphics_count):
    _seed = rng.integers(0, 100)

    function = ConvexFunction(in_features=in_features, seed=_seed, scale = scale)

    gd_info = []
    adam_info = []

    gradient_descent_optimizer(function, x0=x0, opt_info=gd_info)
    adam_optimizer(function, x0=x0, opt_info=adam_info)

    gd_it, gd_val = zip(*[(item['iteration'], item['function_value']) for item in gd_info])
    adam_it, adam_val = zip(*[(item['iteration'], item['function_value']) for item in adam_info])

    plt.figure(figsize=(10, 6))
    sns.set_style("whitegrid")

    sns.lineplot(x=gd_it, y=gd_val, label='Gradient Descent')
    sns.lineplot(x=adam_it, y=adam_val, label='ADAM')

    plt.title(f'Convex optimization (dim=2, scale = {scale}, seed={_seed}): ADAM vs GD')
    plt.xlabel('Iteration')
    plt.ylabel('Function Value (log)')
    plt.yscale('log')
    plt.legend()
    plt.show()

# %% [markdown]
# Convex optimization with noise (dim = 2)

# %%
for i in range(graphics_count):
    _seed = rng.integers(0, 100)

    function = ConvexFunctionWithNoise(in_features=in_features, seed=i, scale = 1.0)

    gd_info = []
    adam_info = []

    gradient_descent_optimizer(function, x0=x0, opt_info=gd_info)
    adam_optimizer(function, x0=x0, opt_info=adam_info)

    gd_it, gd_val = zip(*[(item['iteration'], item['function_value']) for item in gd_info])
    adam_it, adam_val = zip(*[(item['iteration'], item['function_value']) for item in adam_info])

    plt.figure(figsize=(10, 6))
    sns.set_style("whitegrid")

    sns.lineplot(x=gd_it, y=gd_val, label='Gradient Descent')
    sns.lineplot(x=adam_it, y=adam_val, label='ADAM')

    plt.title(f'Convex optimization with noise (dim=2, scale = {scale}, seed={_seed}): ADAM vs GD')
    plt.xlabel('Iteration')
    plt.ylabel('Function Value (log)')
    plt.yscale('log')
    plt.legend()
    plt.show()

# %% [markdown]
# Convex optimization diffrent dims = [3, 5, 10, 100]

# %%
for dim in dims:
    _seed = rng.integers(0, 100)

    function = ConvexFunction(in_features=dim, seed=_seed, scale = scale)

    gd_info = []
    adam_info = []

    x0 = np.zeros(dim)

    gradient_descent_optimizer(function, x0=x0, opt_info=gd_info)
    adam_optimizer(function, x0=x0, opt_info=adam_info)

    gd_it, gd_val = zip(*[(item['iteration'], item['function_value']) for item in gd_info])
    adam_it, adam_val = zip(*[(item['iteration'], item['function_value']) for item in adam_info])

    plt.figure(figsize=(10, 6))
    sns.set_style("whitegrid")

    sns.lineplot(x=gd_it, y=gd_val, label='Gradient Descent')
    sns.lineplot(x=adam_it, y=adam_val, label='ADAM')

    plt.title(f'Convex optimization (dim={dim}, scale = {scale}, seed={_seed}): ADAM vs GD')
    plt.xlabel('Iteration')
    plt.ylabel('Function Value (log)')
    plt.yscale('log')
    plt.legend()
    plt.show()

# %% [markdown]
# Convex optimization with noise diffrent dims = [3, 5, 10, 100]

# %%
for dim in dims:
    _seed = rng.integers(0, 100)

    function = ConvexFunctionWithNoise(in_features=dim, seed=_seed, scale = 1.0)

    gd_info = []
    adam_info = []

    x0 = np.zeros(dim)

    gradient_descent_optimizer(function, x0=x0, opt_info=gd_info)
    adam_optimizer(function, x0=x0, opt_info=adam_info)

    gd_it, gd_val = zip(*[(item['iteration'], item['function_value']) for item in gd_info])
    adam_it, adam_val = zip(*[(item['iteration'], item['function_value']) for item in adam_info])

    plt.figure(figsize=(10, 6))
    sns.set_style("whitegrid")

    sns.lineplot(x=gd_it, y=gd_val, label='Gradient Descent')
    sns.lineplot(x=adam_it, y=adam_val, label='ADAM')

    plt.title(f'Convex optimization with noise (dim={dim}, scale = {scale}, seed={_seed}): ADAM vs GD')
    plt.xlabel('Iteration')
    plt.ylabel('Function Value (log)')
    plt.yscale('log')
    plt.legend()
    plt.show()

# %% [markdown]
# Just couple fully random function test

# %%
for i in range(graphics_count):
    function = ConvexFunction()

    gd_info = []
    adam_info = []

    x0 = np.zeros(function.in_features)

    gradient_descent_optimizer(function, x0=x0, opt_info=gd_info)
    adam_optimizer(function, x0=x0, opt_info=adam_info)

    gd_it, gd_val = zip(*[(item['iteration'], item['function_value']) for item in gd_info])
    adam_it, adam_val = zip(*[(item['iteration'], item['function_value']) for item in adam_info])

    plt.figure(figsize=(10, 6))
    sns.set_style("whitegrid")

    sns.lineplot(x=gd_it, y=gd_val, label='Gradient Descent')
    sns.lineplot(x=adam_it, y=adam_val, label='ADAM')

    print(np.linalg.cond(function.A))

    plt.title(f'Convex optimization (dim={function.in_features}, scale = {function.scale}, seed={function.seed}): ADAM vs GD')
    plt.xlabel('Iteration')
    plt.ylabel('Function Value (log)')
    plt.yscale('log')
    plt.legend()
    plt.show()
# Out:
# 53553.787300533826
# 23.984222350252278
# 203505.21578378286

# %%
for i in range(graphics_count):
    function = ConvexFunctionWithNoise()

    gd_info = []
    adam_info = []

    x0 = np.zeros(function.in_features)

    gradient_descent_optimizer(function, x0=x0, opt_info=gd_info)
    adam_optimizer(function, x0=x0, opt_info=adam_info)

    gd_it, gd_val = zip(*[(item['iteration'], item['function_value']) for item in gd_info])
    adam_it, adam_val = zip(*[(item['iteration'], item['function_value']) for item in adam_info])

    plt.figure(figsize=(10, 6))
    sns.set_style("whitegrid")

    sns.lineplot(x=gd_it, y=gd_val, label='Gradient Descent')
    sns.lineplot(x=adam_it, y=adam_val, label='ADAM')

    plt.title(f'Convex optimization with noise (dim={function.in_features}, scale = {function.scale}, seed={function.seed}): ADAM vs GD')
    plt.xlabel('Iteration')
    plt.ylabel('Function Value (log)')
    plt.yscale('log')
    plt.legend()
    plt.show()
